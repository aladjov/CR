# %% [markdown]
# # Dummy Notebook for Migration Testing
#
# This tests all migration edge cases.

# %%
# --- Configuration ---
PROJECT_NAME = "test"
LIGHT_RUN = False
SAMPLE_FRACTION = None
# ---------------------

from pathlib import Path

data_dir = Path("data")
print(f"Project: {PROJECT_NAME}")
# Out:
# Project: test

# %%
TARGET_COLUMN = "churn"
ENTITY_ID = "customer_id"

# %%
import pandas as pd

df = pd.DataFrame({"a": [1, 2, 3]})
# Out:
#    a
# 0  1
# 1  2
# 2  3

# %% [markdown]
# ## Section 2: Analysis
#
# This section covers:
# - Point one
# - Point two with [link](https://example.com)
#
# > A blockquote
#
# ### Subsection
#
# More text here.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3])
plt.show()

# %%
description = """
This is a multi-line
string literal that spans
multiple lines.
"""
print(description)

# %%
# This cell has only comments
# No actual code here

# %%
def derive_target(df):
    return df["churn"].astype(int)
